# %% [markdown]
# # Generate FIM Inputs
#
# The purpose of this notebook is to generate input arguments that can be used to calculate HAND-based flood maps. The ranges and intervals used to determine the input arguments are computed from historically modeled streamflow.

# %%
# import io
# import json
# import pandas
# import urllib3
# import requests
# from datetime import datetime
# import numpy as np
# import matplotlib.pyplot as plt

# import creds
# import compute_rating_increments as cr

#urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

import s3fs
import xarray
import gis_features as gf
from dask.distributed import Client

# %%
# use a try accept loop so we only instantiate the client
# if it doesn't already exist.
try:
    print(client.dashboard_link)
except:    
    # The client should be customized to your workstation resources.
    # This is configured for a "Large" instance on ciroh.awi.2i2c.cloud
    # client = Client()
    client = Client(n_workers=2, memory_limit='8GB')
    print(client.dashboard_link)
# Out:
# http://127.0.0.1:8787/status
# 2025-10-30 10:09:49,235 - distributed.dashboard.components.scheduler - ERROR - 'open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a'
# Traceback (most recent call last):
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/utils.py", line 811, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2630, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2630, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a'
# 2025-10-30 10:09:49,275 - tornado.application - ERROR - Uncaught exception GET /individual-groups (127.0.0.1)
# HTTPServerRequest(protocol='http', host='127.0.0.1:8787', method='GET', uri='/individual-groups', version='HTTP/1.1', remote_ip='127.0.0.1')
# Traceback (most recent call last):
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/tornado/web.py", line 1790, in _execute
#     result = await result
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/bokeh/server/views/doc_handler.py", line 54, in get
#     session = await self.get_session()
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 145, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/bokeh/server/contexts.py", line 240, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/bokeh/application/application.py", line 190, in initialize_document
#     h.modify_document(doc)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 140, in modify_document
#     self._func(doc)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/toolz/functoolz.py", line 304, in __call__
#     return self._partial(*args, **kwargs)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 4780, in individual_doc
#     fig.update()
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2679, in update
#     self.nodes_layout, self.arrows_layout = self.update_layout()
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/utils.py", line 811, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2630, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2630, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a'
# 2025-10-30 10:19:58,743 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:58167' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5540), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5546), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5521), ('getitem-30f725665ec8c8490e3857d1d780b50f', 0), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5533), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5548), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5545), ('_nanmax_skip-partial-66c468bea2c9475d6bc10dcf04355af4', 27, 0), ('getitem-ceea4106956d003d26792d8fc8d71aed', 0), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5520), ('getitem-7ccf35d51c4559387aee46a409915525', 0), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5523), ('getitem-f9c9cddd36732d37af8a8c205fa7bb15', 0), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5532), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5529), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5541), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5538), ('_nanmax_skip-partial-b959d66fee4b337e23a220d32462dc10', 7, 0), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5544), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5547), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5550), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5522), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5528), ('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 424, 25)} (stimulus_id='handle-worker-cleanup-1761833998.74272')
# 2025-10-30 10:19:58,862 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:58168' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-dafd35578cb53583e4f889e7fadf7de4', ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5537), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5531), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5543), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5549), 'shuffle-taker-288b84a001e8734900860762b8570c3a', ('_nanmax_skip-partial-696a25040e1c9032f61ed1ad7e5847dd', 107, 0), 'shuffle-taker-c7ad413f05cb62c124eb62416d352264', 'shuffle-taker-c7e0dd2382436245dafb6b0fdb215a9f', 'shuffle-taker-57b4ae9b0da38356907ea05099320221', ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5524), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5530), 'shuffle-taker-1426c6247326c65d1c441efc69862409', ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5536), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5542), 'shuffle-taker-a3a2a3ca6ce390ac8b3b4e2df6330384', 'shuffle-taker-a15674954989f17c95082a5c6871cc94', 'shuffle-taker-2aad22a928c27c969ab0da353e67b21a', 'shuffle-taker-32876f7fa788f2080402ec2885f9d8a4', 'shuffle-taker-e32c6eac1526352de19e22c9664732a1', 'shuffle-taker-0e9c0e7b5941538963bebdffd0a2f327', 'shuffle-sorter-30ab408c37adb61f7f6f8cbccc8a4abe', ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5526), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5535), ('nanmax_skip-afd698f85070c32135c52c4e8ca7d5ac', 427, 0), 'original-open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', ('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 425, 21), 'shuffle-taker-79116bc3b3024b7b53bb7d36a8e6415d', 'shuffle-taker-f969b381efc419f5ab2311dec0896397', ('getitem-403bb179675571d3c2e1efd52e3bb148', 0), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5525), ('shuffle-split-646dc7a1768dc7f21474897b4bf662c5', 5534)} (stimulus_id='handle-worker-cleanup-1761833998.862116')
# 2025-10-30 10:19:59,227 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:58167'.
# 2025-10-30 10:19:59,229 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:58168'.

# %% [markdown]
# Load retrospective modeled data.

# %%
# %%time

# load historical streamflow data via retrospective
zarr_url = 's3://noaa-nwm-retrospective-3-0-pds/CONUS/zarr/chrtout.zarr'

# Create an anonymous S3 filesystem
fs = s3fs.S3FileSystem(anon=True)

# Pass the filesystem to xarray
ds = xarray.open_zarr(fs.get_mapper(zarr_url), consolidated=True)
# Out:
# CPU times: user 2.45 s, sys: 398 ms, total: 2.85 s
# Wall time: 5.78 s

# %% [markdown]
# Load river identifiers from GIS layers. These COMIDs will be used to generate inputs for the FIM analysis.

# %%
reaches = gf.collect_reaches_from_gis_layers()
# Out:
# Found 551 rivers in DeSoto
# Found 1163 rivers in MountAscutney
# Found 323 rivers in RoaringRiver
# Found 1704 rivers in SpringfieldGreeneCounty
# Found 1945 rivers in TwoRiversOttauquechee
# Found 1352 rivers in Windham

# %%
reaches
# Out:
#        reachid      huc8   region
# 0      3629135  07140101   DeSoto
# 1      3629127  07140101   DeSoto
# 2      3629119  07140101   DeSoto
# 3      3629097  07140101   DeSoto
# 4      3629089  07140101   DeSoto
# ...        ...       ...      ...
# 7033  10295176  01080203  Windham
# 7034  10295174  01080203  Windham
# 7035  10295172  01080203  Windham
# 7036  10295170  01080203  Windham
# 7037   9332392  01080201  Windham
#
# [7038 rows x 3 columns]

# %% [markdown]
# Get the maximum modeled flow from the retrospective data and use this to determine an upper bound for FIM generation.

# %%
# only search data for ids that exist in the dataset
existing_ids = set(ds.feature_id.values)
valid_ids = [rid for rid in reaches.reachid if rid in existing_ids]
missing_ids = list(set(reaches.reachid) - set(valid_ids))

reaches.loc[reaches.reachid.isin(missing_ids)].to_csv('GIS_reaches_missing_BigQuery_data.csv',
                                                      index=False) 

valid_reaches = reaches.loc[reaches.reachid.isin(valid_ids)]

# %%
# select data that matches our reach_ids, silently drop any that are not found.
dat = ds.sel(feature_id=valid_ids, drop=True)

# %%
# compute the maximum streamflow for all reaches.
maxes = dat['streamflow'].max(dim='time').compute()

# %% [markdown]
# Join these maximum values to the reaches dataset and convert them from CMS to CFS.

# %%
# debugging - remove later
sub = dat['streamflow'].isel(feature_id=range(0,10))

# %%
sub
# Out:
# <xarray.DataArray 'streamflow' (time: 385704, feature_id: 10)> Size: 31MB
# dask.array<getitem, shape=(385704, 10), dtype=float64, chunksize=(672, 10), chunktype=numpy.ndarray>
# Coordinates:
#     elevation   (feature_id) float32 40B dask.array<chunksize=(10,), meta=np.ndarray>
#   * feature_id  (feature_id) int64 80B 3629135 3629127 ... 3629129 3627337
#     gage_id     (feature_id) |S15 150B dask.array<chunksize=(10,), meta=np.ndarray>
#     latitude    (feature_id) float32 40B dask.array<chunksize=(10,), meta=np.ndarray>
#     longitude   (feature_id) float32 40B dask.array<chunksize=(10,), meta=np.ndarray>
#     order       (feature_id) int32 40B dask.array<chunksize=(10,), meta=np.ndarray>
#   * time        (time) datetime64[ns] 3MB 1979-02-01T01:00:00 ... 2023-02-01
# Attributes:
#     grid_mapping:  crs
#     long_name:     River Flow
#     units:         m3 s-1

# %%
# debugging - remove later
ds_rechunked = sub.chunk({"time": 50000, "feature_id": -1})
# ds_rechunked = ds.chunk({"time": 50000, "feature_id": 1000})
ds_rechunked
# Out:
# <xarray.DataArray 'streamflow' (time: 385704, feature_id: 10)> Size: 31MB
# dask.array<rechunk-merge, shape=(385704, 10), dtype=float64, chunksize=(50000, 10), chunktype=numpy.ndarray>
# Coordinates:
#     elevation   (feature_id) float32 40B dask.array<chunksize=(10,), meta=np.ndarray>
#   * feature_id  (feature_id) int64 80B 3629135 3629127 ... 3629129 3627337
#     gage_id     (feature_id) |S15 150B dask.array<chunksize=(10,), meta=np.ndarray>
#     latitude    (feature_id) float32 40B dask.array<chunksize=(10,), meta=np.ndarray>
#     longitude   (feature_id) float32 40B dask.array<chunksize=(10,), meta=np.ndarray>
#     order       (feature_id) int32 40B dask.array<chunksize=(10,), meta=np.ndarray>
#   * time        (time) datetime64[ns] 3MB 1979-02-01T01:00:00 ... 2023-02-01
# Attributes:
#     grid_mapping:  crs
#     long_name:     River Flow
#     units:         m3 s-1

# %%
# debugging - remove later

maxes = sub.max(dim='time').compute()
# Out:
# 2025-10-30 10:19:58,723 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 426, 15))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:58,724 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 424, 11))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:58,724 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 424, 26))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:58,724 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 424, 15))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:58,724 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 424, 30))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:58,724 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 423, 78))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:58,725 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 423, 37))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:58,725 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 423, 87))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:58,725 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 424, 23))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:58,725 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 424, 21))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:58,726 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 423, 89))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:58,726 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_dataset-streamflow-d41c4f8d85fac77c8d1c84af2cb5ea1a', 424, 33))" coro=<Worker.execute() done, defined at /Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-10-30 10:19:59,226 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/utils_comm.py", line 441, in retry_operation
#     return await retry(
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/utils_comm.py", line 420, in retry
#     return await coro()
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:58186 remote=tcp://127.0.0.1:58158>: Stream is closed
# 2025-10-30 10:19:59,249 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 # debugging - remove later
# ----> 3 maxes = sub.max(dim='time').compute()
#
# File ~/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/xarray/core/dataarray.py:1206, in DataArray.compute(self, **kwargs)
#    1181 """Manually trigger loading of this array's data from disk or a
#    1182 remote source into memory and return a new array.
#    1183
#    (...)
#    1203 dask.compute
#    1204 """
#    1205 new = self.copy(deep=False)
# -> 1206 return new.load(**kwargs)
#
# File ~/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/xarray/core/dataarray.py:1174, in DataArray.load(self, **kwargs)
#    1154 def load(self, **kwargs) -> Self:
#    1155     """Manually trigger loading of this array's data from disk or a
#    1156     remote source into memory and return this array.
#    1157
#    (...)
#    1172     dask.compute
#    1173     """
# -> 1174     ds = self._to_temp_dataset().load(**kwargs)
#    1175     new = self._from_temp_dataset(ds)
#    1176     self._variable = new._variable
#
# File ~/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/xarray/core/dataset.py:900, in Dataset.load(self, **kwargs)
#     897 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     899 # evaluate all the chunked arrays simultaneously
# --> 900 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     901     *lazy_data.values(), **kwargs
#     902 )
#     904 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     905     self.variables[k].data = data
#
# File ~/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/xarray/namedarray/daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File ~/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/dask/base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/miniconda3/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# 2025-10-30 10:20:03,503 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/Users/castro/miniconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/castro/miniconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/Users/castro/miniconda3/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/Users/castro/miniconda3/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/castro/miniconda3/lib/python3.10/asyncio/base_events.py", line 1894, in _run_once
#     handle = self._ready.popleft()
# KeyboardInterrupt
# 2025-10-30 10:20:03,555 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/Users/castro/miniconda3/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/castro/miniconda3/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/castro/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/Users/castro/miniconda3/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/Users/castro/miniconda3/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/castro/miniconda3/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/Users/castro/miniconda3/lib/python3.10/selectors.py", line 562, in select
#     kev_list = self._selector.control(None, max_ev, timeout)
# KeyboardInterrupt

# %%
maxes

# %%
maxes_df = maxes.to_dataframe()[["streamflow"]]

# %%
maxes_df
# Out:
#             streamflow
# feature_id
# 101         158.009996
# 179           4.610000
# 181           8.140000
# 183           8.260000
# 185           8.340000
# 843           3.490000
# 845          13.210000
# 847          12.020000
# 849          38.929999
# 851          14.750000

# %%
valid_reaches.loc[valid_reaches.reachid==851]
# Out:
# Empty DataFrame
# Columns: [reachid, huc8, region]
# Index: []

# %%
base_url = "https://arcgis.cuahsi.org/arcgis/rest/services/CIROH-ComRes"

# the following indices correspond to the Flowlines layer
locations = {'DeSoto': 0,
             'MountAscutney': 0,
             'RoaringRiver':13,
             'SpringfieldGreeneCounty':1,
             'TwoRiversOttauquechee': 0,
             'Windham': 0}
params = {
    'where': '1=1',
    'geometryType': 'esriGeometryEnvelope',
    'spatialRel': 'esriSpatialRelIntersects',
    'units': 'esriSRUnit_Foot',
    'outFields': 'COMID,REACHCODE',
    'returnGeometry': 'false',
    'returnDistinctValues': 'true', 
    'returnIdsOnly': 'false',
    'returnCountOnly': 'false',
    'returnExtentOnly': 'false',
    'returnZ': 'false',
    'returnM': 'false',
    'multipatchOption': 'xyFootprint',
    'returnTrueCurves': 'false',
    'returnExceededLimitFeatures': 'false',
    'returnCentroid': 'false',
    'timeReferenceUnknownClient': 'false',
    'sqlFormat': 'none',
    'featureEncoding': 'esriDefault', 
    'f': 'json' 
}

riverids = {}
for locname, layerid in locations.items():
    response = requests.get(f'{base_url}/{locname}/FeatureServer/{layerid}/query', params=params, verify=False)
    
    
    data = response.json()
    if 'error' in data.keys():
        print(f"\n * Error: {locname} - {data['error']['code']} - {data['error']['message']}\n")
        continue
    
    comids = []
    if 'features' in data:
        for feature in data['features']:
            if 'attributes' in feature and 'COMID' in feature['attributes']:
                comids.append({'reachid': feature['attributes']['COMID'],
                               'huc8': feature['attributes']['REACHCODE'][0:8]})

    riverids[locname] = comids
    print(f'Found {len(comids)} rivers in {locname}')
# Out:
# Found 551 rivers in DeSoto
# Found 1163 rivers in MountAscutney
# Found 323 rivers in RoaringRiver
# Found 1704 rivers in SpringfieldGreeneCounty
# Found 1945 rivers in TwoRiversOttauquechee
# Found 1352 rivers in Windham

# %% [markdown]
# Now that we have all of the river identifiers, we can collect streamflow data and compute statistics.

# %%
API_KEY = creds.key
API_URL = creds.url

header = {
    'x-api-key': API_KEY
}

ENDPOINT = f'{API_URL}/analysis-assim'

# %% [markdown]
# ## Collect Data from BigQuery

# %%
from tqdm import tqdm
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor

# %%
                
class GatherData():
    def __init__(self, api_key, api_url='https://nwm-api.ciroh.org/',
                 api_endpoint='analysis-assim', workers=5):
        self.url = f'{api_url}{api_endpoint}'
        self.header =  {
            'x-api-key': api_key
        }
        self.df = None
        self.workers = workers 
        
    def fetch_url(self, params):
        try:
            response = requests.get(self.url,
                                    params=params,
                                    headers=self.header)
            
            # Raise an exception for HTTP errors
            response.raise_for_status()  
            return response
            
        except requests.exceptions.RequestException as e:
            return f"Error fetching {self.url}: {e} -> {params}"

    def fetch_async(self, params_list):

        results = []
        errors = []
        
        # Use ThreadPoolExecutor to make concurrent GET requests
        # TQDM is used to provide a nice looking progress bar
        with ThreadPoolExecutor(max_workers=self.workers) as executor:
            
            # Submit all URLs to the executor
            future_to_url = {executor.submit(self.fetch_url, param): param for param in params_list}
            
            # Process the results as they complete
            for future in tqdm(concurrent.futures.as_completed(future_to_url),
                               total=len(future_to_url),
                               desc="Fetching Data",
                               unit="url",
                               colour="green",  
                               dynamic_ncols=True):
                url = future_to_url[future]
                try:
                    res = future.result()

                    # attempt to get the status code.
                    # if one is not returned, we should log 
                    # it as an error.
                    status_code = res.status_code

                    # otherwise, the 
                    results.append(res)
                    
                except Exception as e:
                    errors.append(f"Exception for {url}: {e}")
                    print(f"Exception for {url}: {e}")
            
            return results, errors
            
    def collect_analysis_data(self, comids, start_time,
                              end_time, parallel=True):
        
        # build a parameters to query
        params = [
            {'comids': comid,
             'start_time': start_time,
             'end_time': end_time,
             'output_format': 'csv'}
            for comid in comids
        ]
        
        # query the api asynchronously with the parameters defined above 
        if parallel:
            responses, errors = self.fetch_async(params)

            with open('errors.txt', 'a') as f:
                for err in errors:
                    f.write(err)
        else:
            responses = []
            for param in params:
                responses.append(self.fetch_url(params))
        
                
        # filter out only the successful responses and 
        # convert them into a single pandas dataframe
        successful_responses = [resp for resp in responses if resp.status_code == 200]
        # return responses, errors
        dfs = [pandas.read_csv(io.StringIO(res.text), sep=',') for res in successful_responses]
        df = pandas.concat(dfs, ignore_index=True)  

        # clean datetime columns and return
        df.time = pandas.to_datetime(df.time)

        self.df = df

# %%
riverids.keys()
# Out:
# dict_keys(['DeSoto', 'MountAscutney', 'RoaringRiver', 'SpringfieldGreeneCounty', 'TwoRiversOttauquechee', 'Windham'])

# %%
for region_name in ['RoaringRiver']:

    print(f'Collecting Data for {region_name}')
    
    reach_ids = [reach['reachid'] for reach in riverids[region_name]]
    
    gather_data = GatherData(creds.key, creds.url, workers = 2)
    
    start_time = '2016-01-01'
    end_time =  datetime.today().strftime('%Y-%m-%d')
    
    gather_data.collect_analysis_data(reach_ids, start_time, end_time)
    df = gather_data.df
    
    df.to_parquet(f'{region_name.lower()}.parquet')
# Out:
# Collecting Data for RoaringRiver
# Fetching Data:   0%|▎                                                                                                                                       | 1/401 [00:15<1:41:37, 15.24s/url]
# Exception for {'comids': 8585734, 'start_time': '2016-01-01', 'end_time': '2025-09-30', 'output_format': 'csv'}: 'str' object has no attribute 'status_code'
# Exception for {'comids': 8585000, 'start_time': '2016-01-01', 'end_time': '2025-09-30', 'output_format': 'csv'}: 'str' object has no attribute 'status_code'
# Fetching Data:   0%|▋                                                                                                                                       | 2/401 [00:28<1:35:40, 14.39s/url]
#
# KeyboardInterrupt

# %% [markdown]
# # Load Parquet and Compute Statistics

# %%
# def cms_to_cfs(flow_cms):
#     return flow_cms * (3.28084**3)

# def m_to_ft(meters):
#     return meters * 3.28084


# def ft_to_m(feet):
#     return feet / 3.28084
    
# def water_year_season(month):
#         if month in [10, 11, 12]:
#             return "Fall"
#         elif month in [1, 2, 3]:
#             return "Winter" 
#         elif month in [4, 5, 6]:
#             return "Spring"
#         elif month in [7, 8, 9]:
#             return "Summer"  
#         else:
#             return None
            
# def get_record_flow(df):
#     """
#     Computes the maximum streamflow for the given series in cubic feet per second.
#     """
#     max_cms = df.streamflow.max()
#     max_cfs = cms_to_cfs(max_cms)

#     return dict(maximum_cms = max_cms,
#                 maximum_cfs = max_cfs)


# def get_seasonal_mean_flows(df):
#     """
#     Computes seasonal average streamflow in cubic feet per second.
#     """

#     # aggregate hourly data to mean daily
#     df_daily = df.resample("D").mean()

#     df_daily["season"] = df_daily.index.month.map(water_year_season)
#     df_daily["water_year"] = df_daily.index.year + (df_daily.index.month >= 10)

#     seasonal_means = (
#         df_daily.groupby(["water_year", "season"])["streamflow"]
#         .mean()
#         .unstack("season") 
#     ).mean()

#     return dict(fall_mean_cfs = cms_to_cfs(seasonal_means['Fall']),
#                 spring_mean_cfs = cms_to_cfs(seasonal_means['Spring']),
#                 summer_mean_cfs = cms_to_cfs(seasonal_means['Summer']),
#                 winter_mean_cfs = cms_to_cfs(seasonal_means['Winter']))

# def get_seasonal_median_flows(df):
#     """
#     Computes median streamflow for each season and averages them over year.
#     """
   
#     # aggregate hourly data to mean daily
#     df_daily = df.resample("D").mean()

#     df_daily["season"] = df_daily.index.month.map(water_year_season)
#     df_daily["water_year"] = df_daily.index.year + (df_daily.index.month >= 10)

#     seasonal_means = (
#         df_daily.groupby(["water_year", "season"])["streamflow"]
#         .median()
#         .unstack("season") 
#     ).mean()

#     return dict(fall_median_cfs = cms_to_cfs(seasonal_means['Fall']),
#                 spring_median_cfs = cms_to_cfs(seasonal_means['Spring']),
#                 summer_median_cfs = cms_to_cfs(seasonal_means['Summer']),
#                 winter_median_cfs = cms_to_cfs(seasonal_means['Winter']))

# def get_stats(df):
#     res = {}
#     res.update(get_record_flow(df))
#     res.update(get_seasonal_median_flows(df))
#     res.update(get_seasonal_mean_flows(df))
#     return res

# %% [markdown]
# # Analyze Roaring River data

# %%
# load all of the known roaring river ids into a dataframe
df_reaches = pandas.DataFrame(riverids['DeSoto'])
df_reaches
# Out:
#      reachid      huc8
# 0    3629135  07140101
# 1    3629127  07140101
# 2    3629119  07140101
# 3    3629097  07140101
# 4    3629089  07140101
# ..       ...       ...
# 546  3629145  07140101
# 547  3629143  07140101
# 548  3630443  07140101
# 549  3630493  07140101
# 550  3627243  07140101
#
# [551 rows x 2 columns]

# %%
# load the data collected and saved into the parquet file
df = pandas.read_parquet('desoto.parquet')
df.set_index('time', inplace=True)
df
# Out:
#                      feature_id    streamflow  velocity
# time
# 2018-09-16 22:00:00     3629119  11061.540039      0.50
# 2018-09-16 23:00:00     3629119  11059.120117      0.50
# 2018-09-17 00:00:00     3629119  11056.700195      0.50
# 2018-09-17 01:00:00     3629119  11052.919922      0.50
# 2018-09-17 02:00:00     3629119  11047.740234      0.50
# ...                         ...           ...       ...
# 2025-09-10 17:00:00     3629143      0.000000      0.01
# 2025-09-10 18:00:00     3629143      0.000000      0.01
# 2025-09-10 19:00:00     3629143      0.000000      0.01
# 2025-09-10 20:00:00     3629143      0.000000      0.01
# 2025-09-10 21:00:00     3629143      0.000000      0.01
#
# [32975280 rows x 3 columns]

# %%
# make sure that we have data for all reach ids.
all_ids = len(df_reaches.reachid.unique())
collected_ids = len(df.feature_id.unique())
print(f'All reaches have data -> {all_ids == collected_ids}')
print(f'Total Number of Reaches = {all_ids}')
print(f'Number of Reaches that have Data = {collected_ids}')
# Out:
# All reaches have data -> False
# Total Number of Reaches = 551
# Number of Reaches that have Data = 542

# %%
# collect data for all missing reaches
missing_ids = df_reaches[~df_reaches.reachid.isin(df.feature_id.unique())]
if len(missing_ids) > 0:
    # TODO: Collect data here.
    for index,  row in missing_ids.iterrows():
        print(row['reachid'])
        
    ids = list(missing_ids.values[:,0])
    gather_data = GatherData(creds.key, creds.url, workers = 1)
    start_time = '2016-01-01'
    end_time =  datetime.today().strftime('%Y-%m-%d')
    gather_data.collect_analysis_data(ids, start_time, end_time)
    dat = gather_data.df
else: 
    print('No missing data to collect')
# Out:
# 3627365
# 3627613
# 3629123
# 3627439
# 3627445
# 3627073
# 3630443
# 3630493
# 3627243
# Fetching Data:  78%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                               | 7/9 [00:47<00:10,  5.31s/url]
# Exception for {'comids': 3630443, 'start_time': '2016-01-01', 'end_time': '2025-10-01', 'output_format': 'csv'}: 'str' object has no attribute 'status_code'
# Fetching Data:  89%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍               | 8/9 [00:48<00:03,  3.95s/url]
# Exception for {'comids': 3630493, 'start_time': '2016-01-01', 'end_time': '2025-10-01', 'output_format': 'csv'}: 'str' object has no attribute 'status_code'
# Fetching Data: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:49<00:00,  5.54s/url]
# Exception for {'comids': 3627243, 'start_time': '2016-01-01', 'end_time': '2025-10-01', 'output_format': 'csv'}: 'str' object has no attribute 'status_code'

# %%
gather_data.collect_analysis_data([3630493], start_time, end_time)
# Out:
# Fetching Data: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.13s/url]
# Exception for {'comids': 3630493, 'start_time': '2016-01-01', 'end_time': '2025-10-01', 'output_format': 'csv'}: 'str' object has no attribute 'status_code'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[249], line 1
# ----> 1 gather_data.collect_analysis_data([3630493], start_time, end_time)
#
# Cell In[225], line 91, in GatherData.collect_analysis_data(self, comids, start_time, end_time, parallel)
#      89 # return responses, errors
#      90 dfs = [pandas.read_csv(io.StringIO(res.text), sep=',') for res in successful_responses]
# ---> 91 df = pandas.concat(dfs, ignore_index=True)
#      93 # clean datetime columns and return
#      94 df.time = pandas.to_datetime(df.time)
#
# File ~/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/Documents/work/com_res/fim/.venv/lib/python3.10/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
df

# %%
# apply the statistics function to every feature_id in our dataset
stats = df.groupby('feature_id').apply(get_stats, include_groups=False)

# converte the series above into a dataframe in which each statistic is represented as a column
stats = pandas.DataFrame(stats.tolist(), index=stats.index).reset_index().rename(columns={"index": "feature_id"})

stats
# Out:
#      feature_id  maximum_cms   maximum_cfs  fall_median_cfs  \
# 0       8584816     9.420000    332.664195         0.151349
# 1       8584818    17.789999    628.247946         0.201798
# 2       8584830     6.110000    215.772622         0.302697
# 3       8584832     6.060000    214.006899         0.302697
# 4       8584836    29.099998   1027.656846         0.353147
# ..          ...          ...           ...              ...
# 396     8589596   623.440002  22016.578021      1014.643003
# 397     8589598   624.640015  22058.956056      1016.231112
# 398     8589600    28.420000   1003.642927         0.816652
# 399     8589606   628.429993  22192.797880      1014.831135
# 400     8598016          NaN           NaN              NaN
#
#      spring_median_cfs  summer_median_cfs  winter_median_cfs  fall_mean_cfs  \
# 0             0.365759           0.044143           0.359453       0.404612
# 1             0.405698           0.044143           0.422515       0.412215
# 2             0.554945           0.088287           0.706293       0.322093
# 3             0.578068           0.088287           0.706293       0.324518
# 4             0.838723           0.088287           0.850285       0.955086
# ..                 ...                ...                ...            ...
# 396        2233.165155        1169.377569        1449.512673    1029.966426
# 397        2236.408639        1170.370704        1451.360381    1032.130827
# 398           1.486159           0.264860           1.893959       1.899854
# 399        2238.006207        1163.096912        1456.216151    1029.866086
# 400                NaN                NaN                NaN            NaN
#
#      spring_mean_cfs  summer_mean_cfs  winter_mean_cfs
# 0           1.301210         0.160039         0.825325
# 1           1.178485         0.190158         0.707380
# 2           0.632222         0.118801         0.717859
# 3           0.655108         0.132825         0.719808
# 4           2.943300         0.410236         1.784595
# ..               ...              ...              ...
# 396      2402.815532      1198.452754      1612.928333
# 397      2407.585439      1199.533158      1616.157269
# 398         4.568732         1.062457         3.232303
# 399      2402.846867      1198.503790      1613.801285
# 400              NaN              NaN              NaN
#
# [401 rows x 11 columns]

# %%
# compute rating curve increments based on min and max flow values.

# %%
from utils import ratingcurve

import importlib
importlib.reload(ratingcurve)
# Out:
# <module 'utils.ratingcurve' from '/Users/castro/Documents/work/com_res/fim/utils/ratingcurve.py'>

# %%
rc = ratingcurve.RatingCurve(11010001)

# %%
rc.get_flow(8589606, 1.2)
# Out:
# 287.1842952435199

# %%
cms_to_cfs(287.1842952435199)
# Out:
# 10141.818647785014

# %%
import time
import math

import numpy
import compute_rating_increments as rc

def round_up_to_step(x, step=0.5):
    return math.ceil(x / step) * step
    
def get_fim_increments(reachid, huc_id, max_cms, buffer=.25, step_ft=0.5):
    
    
    max_stage_ft = m_to_ft(rc.get_stage(huc_id, reachid, max_cms * (1+buffer)))

    max_stage_ft = max(max_stage_ft, 10)
    max_stage_ft = round_up_to_step(max_stage_ft, step_ft)

    print(f'Computing flow rates for {reachid}, [max={max_stage_ft}]...', end='', flush=True)
    st = time.time()

    #print('Loading rating curve...', end='', flush=True)
    dat = rc.__load_rating_curve(huc_id, reachid)
    # since each feature_id is associated with multiple HydroID's,
    # we'll just consider the first one to determine the bounds of
    # our calculation
    group = dat.groupby("HydroID").get_group(
        list(dat.groupby("HydroID").groups.keys())[0]
    )
    #print('done')
    
    fim_args = []
    
    for i in numpy.arange(step_ft, max_stage_ft + 0.1, step_ft):
        stage_in_m = ft_to_m(i)
        flow_in_m = rc.interpolate_y(group, "stage", "discharge_cms", stage_in_m)

        fim_args.append({
                            'ft': i,
                            'm': stage_in_m,
                            'cms': flow_in_m,
                            'cfs': cms_to_cfs(flow_in_m)
                        })
   
    print(f'done [elapsed {round(time.time() - st, 1)} sec]')                      
    return fim_args

# %%
#reach_id = 8584816
from utils import ratingcurve

importlib.reload(ratingcurve)

buffer = 0.1
step_ft=0.5


fim_increments = {}
# loop through huc8s
for huc_id, data in df_reaches.groupby(df_reaches.huc8):
    rc = ratingcurve.RatingCurve(huc8)

    # loop through reaches in the huc8
    for rid in data.reachid.values:
        fim_args = []
        
        # load the stats
        reach_stats = stats.loc[stats.feature_id == rid]
    
        # compute fim increments
        #fim_inc = get_fim_increments(rid, huc_id, reach_stats.maximum_cms.item())
        max_cms = reach_stats.maximum_cms.item()
        if numpy.isnan(max_cms):
            print(f'Huc8 = {huc_id}, reachid = {rid} contains Nan data. Skipping.')
            continue

        
        try:
            max_stage_ft = m_to_ft(rc.get_stage(rid, max_cms * (1+buffer)))
        except Exception as e:
            print(e)
            continue

        
        max_stage_ft = max(max_stage_ft, 10)
        max_stage_ft = round_up_to_step(max_stage_ft, step_ft)
    
        print(f'Computing flow rates for {rid}, [max={max_stage_ft}]...', end='', flush=True)
        st = time.time()
        
        
        for i in numpy.arange(step_ft, max_stage_ft + 0.1, step_ft):
            stage_in_m = ft_to_m(i)
            flow_in_cms = rc.get_flow(rid, stage_in_m)
    
            fim_args.append({
                                'ft': i,
                                'm': stage_in_m,
                                'cms': flow_in_cms,
                                'cfs': cms_to_cfs(flow_in_cms),
                                'huc8': huc_id,
                            })
       
        print(f'done [elapsed {round(time.time() - st, 1)} sec]')                      
    
        fim_increments[rid] = fim_args
# Out:
# Computing flow rates for 8585734, [max=13.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8585000, [max=13.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8584992, [max=14.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8584984, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8584978, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8584962, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8584940, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8584928, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8584920, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8585720, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8585718, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8584904, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8584900, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8584886, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8585178, [max=14.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8585158, [max=14.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8585160, [max=14.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8585142, [max=11.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8585130, [max=22.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8585128, [max=11.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8585124, [max=11.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8585102, [max=12.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8585080, [max=14.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8585070, [max=13.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8585022, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8585002, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8584996, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8584888, [max=10.0]...done [elapsed 0.0 sec]
# No rating curve data found for huc8=11010001 and reach_id= 8586644
# Computing flow rates for 8589580, [max=16.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8589598, [max=21.0]...done [elapsed 0.2 sec]
# No rating curve data found for huc8=11010001 and reach_id= 8586678
# No rating curve data found for huc8=11010001 and reach_id= 8589590
# Computing flow rates for 8589596, [max=18.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8589606, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8586496, [max=12.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8589244, [max=11.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8586612, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8586654, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8586706, [max=10.0]...done [elapsed 0.1 sec]
# No rating curve data found for huc8=11010001 and reach_id= 8586672
# Computing flow rates for 8586812, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8586896, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8586624, [max=12.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8586640, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8586472, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8586464, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8586416, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8586446, [max=13.0]...done [elapsed 0.1 sec]
# No rating curve data found for huc8=11010001 and reach_id= 8586434
# No rating curve data found for huc8=11010001 and reach_id= 8589520
# Computing flow rates for 8586420, [max=12.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8586390, [max=12.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8586358, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8586318, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8585438, [max=11.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8586308, [max=11.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8585382, [max=11.5]...done [elapsed 0.1 sec]
# Computing flow rates for 8585322, [max=10.5]...done [elapsed 0.0 sec]
# Computing flow rates for 8585342, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8585226, [max=10.5]...done [elapsed 0.0 sec]
# Computing flow rates for 8585252, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8585274, [max=10.5]...done [elapsed 0.0 sec]
# Computing flow rates for 8585314, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8585316, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8585318, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8584982, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8584972, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8584944, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8584912, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8584894, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8584852, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8584832, [max=10.0]...done [elapsed 0.0 sec]
# Computing flow rates for 8586398, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8585454, [max=10.0]...done [elapsed 0.1 sec]
# Computing flow rates for 8585268, [max=10.0]...done [elapsed 0.0 sec]
# No rating curve data found for huc8=11010001 and reach_id= 8
contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585776 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585790 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585788 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585814 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585986 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585982 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585980 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585978 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585966 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585958 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585922 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585914 contains Nan data. Skipping.
# No rating curve data found for huc8=11010001 and reach_id= 8585910
# Huc8 = 11010001, reachid = 8585908 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585902 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585878 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585866 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585854 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585840 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585836 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8598016 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589568 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589566 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589564 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589542 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589540 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589538 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589536 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589534 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589526 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589522 contains Nan data. Skipping.
# No rating curve data found for huc8=11010001 and reach_id= 8589518
# Huc8 = 11010001, reachid = 8589514 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589512 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589508 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589506 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8589498 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586098 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586096 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586094 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586068 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586056 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586050 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586048 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586044 contains Nan data. Skipping.
# No rating curve data found for huc8=11010001 and reach_id= 8586042
# Huc8 = 11010001, reachid = 8586040 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586038 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586034 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586032 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586022 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586018 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8586012 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585834 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585832 contains Nan data. Skipping.
# Huc8 = 11010001, reachid = 8585822 contains Nan data. Skipping.

# %%
fim_increments
# Out:
# {8585734: [{'ft': 0.5,
#    'm': 0.15239999512320015,
#    'cms': 0.8138755446260789,
#    'cfs': 28.74174637044747,
#    'huc8': '11010001'},
#   {'ft': 1.0,
#    'm': 0.3047999902464003,
#    'cms': 1.6277510892521578,
#    'cfs': 57.48349274089494,
#    'huc8': '11010001'},
#   {'ft': 1.5,
#    'm': 0.4571999853696005,
#    'cms': 3.847128460898506,
#    'cfs': 135.86007247395023,
#    'huc8': '11010001'},
#   {'ft': 2.0,
#    'm': 0.6095999804928006,
#    'cms': 6.066505922496977,
#    'cfs': 214.23665538363505,
#    'huc8': '11010001'},
#   {'ft': 2.5,
#    'm': 0.7619999756160007,
#    'cms': 9.81853271616244,
#    'cfs': 346.738243852178,
#    'huc8': '11010001'},
#   {'ft': 3.0,
#    'm': 0.914399970739201,
#    'cms': 13.570559706007046,
#    'cfs': 479.23983924872266,
#    'huc8': '11010001'},
#   {'ft': 3.5,
#    'm': 1.066799965862401,
#    'cms': 18.824405339823308,
#    'cfs': 664.7776646247221,
#    'huc8': '11010001'},
#   {'ft': 4.0,
#    'm': 1.2191999609856012,
#    'cms': 24.07825126198881,
#    'cfs': 850.3155001836798,
#    'huc8': '11010001'},
#   {'ft': 4.5,
#    'm': 1.3715999561088015,
#    'cms': 30.30140052282013,
#    'cfs': 1070.083963385787,
#    'huc8': '11010001'},
#   {'ft': 5.0,
#    'm': 1.5239999512320015,
#    'cms': 36.52455003179316,
#    'cfs': 1289.852435350937,
#    'huc8': '11010001'},
#   {'ft': 5.5,
#    'm': 1.6763999463552017,
#    'cms': 49.662544946424184,
#    'cfs': 1753.8163916902804,
#    'huc8': '11010001'},
#   {'ft': 6.0,
#    'm': 1.828799941478402,
#    'cms': 62.80054207380644,
#    'cfs': 2217.780426172204,
#    'huc8': '11010001'},
#   {'ft': 6.5,
#    'm': 1.981199936601602,
#    'cms': 79.72316318249904,
#    'cfs': 2815.397208050918,
#    'huc8': '11010001'},
#   {'ft': 7.0,
#    'm': 2.133599931724802,
#    'cms': 96.6457857444878,
#    'cfs': 3413.014041252307,
#    'huc8': '11010001'},
#   {'ft': 7.5,
#    'm': 2.2859999268480022,
#    'cms': 117.90650213613553,
#    'cfs': 4163.8292269616895,
#    'huc8': '11010001'},
#   {'ft': 8.0,
#    'm': 2.4383999219712025,
#    'cms': 139.16722047125018,
#    'cfs': 4914.644481303964,
#    'huc8': '11010001'},
#   {'ft': 8.5,
#    'm': 2.5907999170944027,
#    'cms': 164.98887129769975,
#    'cfs': 5826.527561979452,
#    'huc8': '11010001'},
#   {'ft': 9.0,
#    'm': 2.743199912217603,
#    'cms': 190.81052445934796,
#    'cfs': 6738.410725121709,
#    'huc8': '11010001'},
#   {'ft': 9.5,
#    'm': 2.895599907340803,
#    'cms': 220.6523718975716,
#    'cfs': 7792.265722926159,
#    'huc8': '11010001'},
#   {'ft': 10.0,
#    'm': 3.047999902464003,
#    'cms': 250.4942216514284,
#    'cfs': 8846.120802506428,
#    'huc8': '11010001'},
#   {'ft': 10.5,
#    'm': 3.2003998975872032,
#    'cms': 284.0095695909727,
#    'cfs': 10029.70425867017,
#    'huc8': '11010001'},
#   {'ft': 11.0,
#    'm': 3.3527998927104035,
#    'cms': 317.52491988155737,
#    'cfs': 11213.287797860125,
#    'huc8': '11010001'},
#   {'ft': 11.5,
#    'm': 3.5051998878336037,
#    'cms': 354.73285453772485,
#    'cfs': 12527.273735780247,
#    'huc8': '11010001'},
#   {'ft': 12.0,
#    'm': 3.657599882956804,
#    'cms': 391.94079179347364,
#    'cfs': 13841.259765503724,
#    'huc8': '11010001'},
#   {'ft': 12.5,
#    'm': 3.8099998780800037,
#    'cms': 433.4848648557428,
#    'cfs': 15308.375000793985,
#    'huc8': '11010001'},
#   {'ft': 13.0,
#    'm': 3.962399873203204,
#    'cms': 475.0289412481669,
#    'cfs': 16775.49035368757,
#    'huc8': '11010001'}],
#  8585000: [{'ft': 0.5,
#    'm': 0.15239999512320015,
#    'cms': 0.912821541055399,
#    'cfs': 32.23599159322203,
#    'huc8': '11010001'},
#   {'ft': 1.0,
#    'm': 0.3047999902464003,
#    'cms': 1.825643082110798,
#    'cfs': 64.47198318644406,
#    'huc8': '11010001'},
#   {'ft': 1.5,
#    'm': 0.4571999853696005,
#    'cms': 4.471389155988575,
#    'cfs': 157.9056329847545,
#    'huc8': '11010001'},
#   {'ft': 2.0,
#    'm': 0.6095999804928006,
#    'cms': 7.117135340773529,
#    'cfs': 251.3392866997153,
#    'huc8': '11010001'},
#   {'ft': 2.5,
#    'm': 0.7619999756160007,
#    'cms': 11.486729035477715,
#    'cfs': 405.65004655034363,
#    'huc8': '11010001'},
#   {'ft': 3.0,
#    'm': 0.914399970739201,
#    'cms': 15.856322950834418,
#    'cfs': 559.9608141932428,
#    'huc8': '11010001'},
#   {'ft': 3.5,
#    'm': 1.066799965862401,
#    'cms': 22.527680240011268,
#    'cfs': 795.5575960577864,
#    'huc8': '11010001'},
#   {'ft': 4.0,
#    'm': 1.2191999609856012,
#    'cms': 29.199037971126778,
#    'cfs': 1031.154393529248,
#    'huc8': '11010001'},
#   {'ft': 4.5,
#    'm': 1.3715999561088015,
#    'cms': 39.38246024432833,
#    'cfs': 1390.7785917154654,
#    'huc8': '11010001'},
#   {'ft': 5.0,
#    'm': 1.5239999512320015,
#    'cms': 49.56588341661862,
#    'cfs': 1750.402821652705,
#    'huc8': '11010001'},
#   {'ft': 5.5,
#    'm': 1.6763999463552017,
#    'cms':
#    'cfs': 16160.244539023593,
#    'huc8': '11010001'},
#   {'ft': 16.0,
#    'm': 4.876799843942405,
#    'cms': 488.56767856693017,
#    'cfs': 17253.606395828614,
#    'huc8': '11010001'},
#   {'ft': 16.5,
#    'm': 5.029199839065605,
#    'cms': 521.5461414530585,
#    'cfs': 18418.229933443065,
#    'huc8': '11010001'},
#   {'ft': 17.0,
#    'm': 5.181599834188805,
#    'cms': 554.5246064055247,
#    'cfs': 19582.85354402956,
#    'huc8': '11010001'}],
#  8585176: [{'ft': 0.5,
#    'm': 0.15239999512320015,
#    'cms': 0.6627793628100094,
#    'cfs': 23.405834554476026,
#    'huc8': '11010001'},
#   {'ft': 1.0,
#    'm': 0.3047999902464003,
#    'cms': 1.3255587256200188,
#    'cfs': 46.81166910895205,
#    'huc8': '11010001'},
#   {'ft': 1.5,
#    'm': 0.4571999853696005,
#    'cms': 3.2713826184169412,
#    'cfs': 115.52779797853286,
#    'huc8': '11010001'},
#   {'ft': 2.0,
#    'm': 0.6095999804928006,
#    'cms': 5.217206593328719,
#    'cfs': 184.2439297479727,
#    'huc8': '11010001'},
#   {'ft': 2.5,
#    'm': 0.7619999756160007,
#    'cms': 8.548855088291539,
#    'cfs': 301.8999972757155,
#    'huc8': '11010001'},
#   {'ft': 3.0,
#    'm': 0.914399970739201,
#    'cms': 11.880503760639925,
#    'cfs': 419.5560710677711,
#    'huc8': '11010001'},
#   {'ft': 3.5,
#    'm': 1.066799965862401,
#    'cms': 16.54237642933565,
#    'cfs': 584.1885664654958,
#    'huc8': '11010001'},
#   {'ft': 4.0,
#    'm': 1.2191999609856012,
#    'cms': 21.204249353434438,
#    'cfs': 748.8210708826954,
#    'huc8': '11010001'},
#   {'ft': 4.5,
#    'm': 1.3715999561088015,
#    'cms': 27.799990140273415,
#    'cfs': 981.7474809121767,
#    'huc8': '11010001'},
#   {'ft': 5.0,
#    'm': 1.5239999512320015,
#    'cms': 34.39573142218268,
#    'cfs': 1214.6739084249018,
#    'huc8': '11010001'},
#   {'ft': 5.5,
#    'm': 1.6763999463552017,
#    'cms': 42.154370479219224,
#    'cfs': 1488.6676872398732,
#    'huc8': '11010001'},
#   {'ft': 6.0,
#    'm': 1.828799941478402,
#    'cms': 49.91300990838317,
#    'cfs': 1762.6614791964005,
#    'huc8': '11010001'},
#   {'ft': 6.5,
#    'm': 1.981199936601602,
#    'cms': 58.82965171457432,
#    'cfs': 2077.5497430862047,
#    'huc8': '11010001'},
#   {'ft': 7.0,
#    'm': 2.133599931724802,
#    'cms': 67.74629396543855,
#    'cfs': 2392.438022679492,
#    'huc8': '11010001'},
#   {'ft': 7.5,
#    'm': 2.2859999268480022,
#    'cms': 77.68892700823908,
#    'cfs': 2743.5588286276475,
#    'huc8': '11010001'},
#   {'ft': 8.0,
#    'm': 2.4383999219712025,
#    'cms': 87.63156051068368,
#    'cfs': 3094.6796508079824,
#    'huc8': '11010001'},
#   {'ft': 8.5,
#    'm': 2.5907999170944027,
#    'cms': 98.56451156515571,
#    'cfs': 3480.773210643989,
#    'huc8': '11010001'},
#   {'ft': 9.0,
#    'm': 2.743199912217603,
#    'cms': 109.49746312667058,
#    'cfs': 3866.8667883860458,
#    'huc8': '11010001'},
#   {'ft': 9.5,
#    'm': 2.895599907340803,
#    'cms': 121.70323604584487,
#    'cfs': 4297.909632484967,
#    'huc8': '11010001'},
#   {'ft': 10.0,
#    'm': 3.047999902464003,
#    'cms': 133.90900969816465,
#    'cfs': 4728.95250247468,
#    'huc8': '11010001'},
#   {'ft': 10.5,
#    'm': 3.2003998975872032,
#    'cms': 146.84440491164827,
#    'cfs': 5185.761717203274,
#    'huc8': '11010001'},
#   {'ft': 11.0,
#    'm': 3.3527998927104035,
#    'cms': 159.77980059208994,
#    'cfs': 5642.570948422338,
#    'huc8': '11010001'},
#   {'ft': 11.5,
#    'm': 3.5051998878336037,
#    'cms': 174.07562903823631,
#    'cfs': 6147.423413971407,
#    'huc8': '11010001'},
#   {'ft': 12.0,
#    'm': 3.657599882956804,
#    'cms': 188.37145844212804,
#    'cfs': 6652.275913342937,
#    'huc8': '11010001'},
#   {'ft': 12.5,
#    'm': 3.8099998780800037,
#    'cms': 203.85090830011347,
#    'cfs': 7198.927578588244,
#    'huc8': '11010001'},
#   {'ft': 13.0,
#    'm': 3.962399873203204,
#    'cms': 219.33035906712013,
#    'cfs': 7745.5792759353335,
#    'huc8': '11010001'},
#   {'ft': 13.5,
#    'm': 4.114799868326404,
#    'cms': 235.98100246630585,
#    'cfs': 8333.591254725077,
#    'huc8': '11010001'},
#   {'ft': 14.0,
#    'm': 4.267199863449604,
#    'cms': 252.6316468399246,
#    'cfs': 8921.603267926603,
#    'huc8': '11010001'},
#   {'ft': 14.5,
#    'm': 4.419599858572805,
#    'cms': 270.36166420912105,
#    'cfs': 9547.732982394427,
#    'huc8': '11010001'},
#   {'ft': 15.0,
#    'm': 4.5719998536960045,
#    'cms': 288.09168254543647,
#    'cfs': 10173.86273101574,
#    'huc8': '11010001'},
#   {'ft': 15.5,
#    'm': 4.724399848819205,
#    'cms': 305.9368158025496,
#    'cfs': 10804.057725089959,
#    'huc8': '11010001'},
#   {'ft': 16.0,
#    'm': 4.876799843942405,
#    'cms': 323.7819491701731,
#    'cfs': 11434.252723066815,
#    'huc8': '11010001'},
#   {'ft': 16.5,
#    'm': 5.029199839065605,
#    'cms': 343.709307439412,
#    'cfs': 12137.980806542577,
#    'huc8': '11010001'},
#   {'ft': 17.0,
#    'm': 5.181599834188805,
#    'cms': 363.6366678408515,
#    'cfs': 12841.7089653163,
#    'huc8': '11010001'},
#   {'ft': 17.5,
#    'm': 5.333999829312005,
#    'cms': 383.9004855182655,
#    'cfs': 13557.319001797745,
#    'huc8': '11010001'},
#   {'ft': 18.0,
#    'm': 5.486399824435206,
#    'cms': 404.1643035617455,
#    'cfs': 14272.92905120669,
#    'huc8': '11010001'},
#   {'ft': 18.5,
#    'm': 5.638799819558406,
#    'cms': 425.50054633139683,
#    'cfs': 15026.41142604,
#    'huc8': '11010001'},
#   {'ft': 19.0,
#    'm': 5.791199814681606,
#    'cms': 446.836790336483,
#    'cfs': 15779.893844502283,
#    'huc8': '11010001'}],
#  8585362: [{'ft': 0.5,
#    'm': 0.15239999512320015,
#    'cms': 1.6612003747418385,
#    'cfs': 58.66474322343497,
#    'huc8': '11010001'},
#   {'ft': 1.0,
#    'm': 0.3047999902464003,
#    'cms': 3.322400749483677,
#    'cfs': 117.32948644686994,
#    'huc8': '11010001'},
#   {'ft': 1.5,
#    'm': 0.4571999853696005,
#    'cms': 8.758388044984368,
#    'cfs': 309.29958451885125,
#    'huc8': '11010001'},
#   {'ft': 2.0,
#    'm': 0.6095999804928006,
#    'cms': 14.194375582071434,
#    'cfs': 501.2696911223756,
#    'huc8': '11010001'},
#   {'ft': 2.5,
#    'm': 0.7619999756160007,
#    'cms': 22.916768610580938,
#    'cfs': 809.2981235087519,
#    'huc8': '11010001'},
#   {'ft': 3.0,
#    'm': 0.914399970739201,
#    'cms': 31.639162059750408,
#    'cfs': 1117.3265707505961,
#    'huc8': '11010001'},
#   {'ft': 3.5,
#    'm': 1.066799965862401,
#    'cms': 43.79848202535097,
#    'cfs': 1546.7289441183473,
#    'huc8': '11010001'},
#   {'ft': 4.0,
#    'm': 1.2191999609856012,
#    'cms': 55.95780265084157,
#    'cfs': 1976.1313407898976,
#    'huc8': '11010001'},
#   {'ft': 4.5,
#    'm': 1.3715999561088015,
#    'cms': 71.2131191165312,
#    'cfs': 2514.8678092252617,
#    'huc8': '11010001'},
#   {'ft': 5.0,
#    'm': 1.5239999512320015,
#    'cms': 86.46843637479594,
#    'cfs': 3053.6043056501544,
#    'huc8': '11010001'},
#   {'ft': 5.5,
#    'm': 1.6763999463552017,
#    'cms': 104.83085041560379,
#    'cfs': 3702.0668999556715,
#    'huc8': '11010001'},
#   {'ft': 6.0,
#    'm': 1.828799941478402,
#    'cms': 123.19326545068294,
#    'cfs': 4350.529529373552,
#    'huc8': '11010001'},
#   {'ft': 6.5,
#    'm': 1.981199936601602,
#    'cms': 144.49547171639932,
#    'cfs': 5102.809916298644,
#    'huc8': '11010001'},
#   {'ft': 7.0,
#    'm': 2.133599931724802,
#    'cms': 165.79767911099594,
#    'cfs': 5855.09034308977,
#    'huc8': '11010001'},
#   {'ft': 7.5,
#    'm': 2.2859999268480022,
#    'cms': 190.07833808273872,
#    'cfs': 6712.553804771475,
#    'huc8': '11010001'},
#   {'ft': 8.0,
#    'm': 2.4383999219712025,
#    'cms': 214.3589983888284,
#    'cfs': 7570.017313575201,
#    'huc8': '11010001'},
#   {'ft': 8.5,
#    'm': 2.5907999170944027,
#    'cms': 241.04805665771983,
#    'cfs': 8512.532601932953,
#    'huc8': '11010001'},
#   {'ft': 9.0,
#    'm': 2.743199912217603,
#    'cms': 267.7371161597116,
#    'cfs': 9455.047933837237,
#    'huc8': '11010001'},
#   {'ft': 9.5,
#    'm': 2.895599907340803,
#    'cms': 297.48340422988736,
#    'cfs': 10505.528284082993,
#    'huc8': '11010001'},
#   {'ft': 10.0,
#    'm': 3.047999902464003,
#    'cms': 327.22969406102766,
#    'cfs': 11556.00869651663,
#    'huc8': '11010001'}],
#  8586586: [{'ft': 0.5,
#    'm': 0.15239999512320015,
#    'cms': 1.3855064661632033,
#    'cfs': 48.9287037901762,
#    'huc8': '11010001'},
#   {'ft': 1.0,
#    'm': 0.3047999902464003,
#    'cms': 2.7710129323264066,
#    'cfs': 97.8574075803524,
#    'huc8': '11010001'},
#   {'ft': 1.5,
#    'm': 0.4571999853696005,
#    'cms': 6.132711748544388,
#    'cfs': 216.57469228997175,
#    'huc8': '11010001'},
#   {'ft': 2.0,
#    'm': 0.6095999804928006,
#    'cms': 9.494410691238686,
#    'cfs': 335.2919814660605,
#    'huc8': '11010001'},
#   {'ft': 2.5,
#    'm': 0.7619999756160007,
#    'cms': 16.600925494227994,
#    'cfs': 586.2562073775172,
#    'huc8': '11010001'},
#   {'ft': 3.0,
#    'm': 0.914399970739201,
#    'cms': 23.707440776553796,
#    'cfs': 837.220450216584,
#    'huc8': '11010001'},
#   {'ft': 3.5,
#    'm': 1.066799965862401,
#    'cms': 33.969356871374345,
#    'cfs': 1199.6166318190826,
#    'huc8': '11010001'},
#   {'ft': 4.0,
#    'm': 1.2191999609856012,
#    'cms': 44.23127357203198,
#    'cfs': 1562.0128348165183,
#    'huc8': '11010001'},
#   {'ft': 4.5,
#    'm': 1.3715999561088015,
#    'cms': 57.94909349705864,
#    'cfs': 2046.4531201204948,
#    'huc8': '11010001'},
#   {'ft': 5.0,
#    'm': 1.5239999512320015,
#    'cms': 71.66691430679674,
#    'cfs': 2530.893436667764,
#    'huc8': '11010001'},
#   {'ft': 5.5,
#    'm': 1.6763999463552017,
#    'cms': 88.61483855517437,
#    'cfs': 3129.403790577245,
#    'huc8': '11010001'},
#   {'ft': 6.0,
#    'm': 1.828799941478402,
#    'cms': 105.56276383718543,
#    'cfs': 3727.9141809891503,
#    'huc8': '11010001'},
#   {'ft': 6.5,
#    'm': 1.981199936601602,
#    'cms': 126.14511218217521,
#    'cfs': 4454.773022916491,
#    'huc8': '11010001'},
#   {'ft': 7.0,
#    'm': 2.133599931724802,
#    'cms': 146.727461922784,
#    'cfs': 5181.631914129656,
#    'huc8': '11010001'},
#   {'ft': 7.5,
#    'm': 2.2859999268480022,
#    'cms': 170.54124033490828,
#    'cfs': 6022.60764286687,
#    'huc8': '11010001'},
#   {'ft': 8.0,
#    'm': 2.4383999219712025,
#    'cms': 194.3550201947133,
#    'cfs': 6863.583422728451,
#    'huc8': '11010001'},
#   {'ft': 8.5,
#    'm': 2.5907999170944027,
#    'cms': 220.8429952587189,
#    'cfs': 7798.9975240406575,
#    'huc8': '11010001'},
#   {'ft': 9.0,
#    'm': 2.743199912217603,
#    'cms': 247.33097169191313,
#    'cfs': 8734.411673705308,
#    'huc8': '11010001'},
#   {'ft': 9.5,
#    'm': 2.895599907340803,
#    'cms': 276.676510769884,
#    'cfs': 9770.739705493754,
#    'huc8': '11010001'},
#   {'ft': 10.0,
#    'm': 3.047999902464003,
#    'cms': 306.0220514938118,
#    'cfs': 10807.067795408626,
#    'huc8': '11010001'}],
#  8589584: [{'ft': 0.5,
#    'm': 0.15239999512320015,
#    'cms': 3.4127497184531004,
#    'cfs': 120.52013048095705,
#    'huc8': '11010001'},
#   {'ft': 1.0,
#    'm': 0.3047999902464003,
#    'cms': 6.825499436906201,
#    'cfs': 241.0402609619141,
#    'huc8': '11010001'},
#   {'ft': 1.5,
#    'm': 0.4571999853696005,
#    'cms': 14.572421871489805,
#    'cfs': 514.6202711201364,
#    'huc8': '11010001'},
#   {'ft': 2.0,
#    'm': 0.6095999804928006,
#    'cms': 22.319344583460477,
#    'cfs': 788.2002910741915,
#    'huc8': '11010001'},
#   {'ft': 2.5,
#    'm': 0.7619999756160007,
#    'cms': 33.9519326539431,
#    'cfs': 1199.001301328544,
#    'huc8': '11010001'},
#   {'ft': 3.0,
#    'm': 0.914399970739201,
#    'cms': 45.584521221790965,
#    'cfs': 1609.8023291471857,
#    'huc8': '11010001'},
#   {'ft': 3.5,
#    'm': 1.066799965862401,
#    'cms': 60.28077296469344,
#    'cfs': 2128.7956113262344,
#    'huc8': '11010001'},
#   {'ft': 4.0,
#    'm': 1.2191999609856012,
#    'cms': 74.97702529581937,
#    'cfs': 2647.7889142782005,
#    'huc8': '11010001'},
#   {'ft': 4.5,
#    'm': 1.3715999561088015,
#    'cms': 92.4657713376794,
#    'cfs': 3265.398211413729,
#    'huc8': '11010001'},
#   {'ft': 5.0,
#    'm': 1.5239999512320015,
#    'cms': 109.95451809441798,
#    'cfs': 3883.0075337949575,
#    'huc8': '11010001'},
#   {'ft': 5.5,
#    'm': 1.6763999463552017,
#    'cms': 130.08986876067115,
#    'cfs': 4594.08080015702,
#    'huc8': '11010001'},
#   {'ft': 6.0,
#    'm': 1.828799941478402,
#    'cms': 150.22522027383783,
#    'cfs': 5305.1540964275555,
#    'huc8': '11010001'},
#   {'ft': 6.5,
#    'm': 1.981199936601602,
#    'cms': 172.7492493110102,
#    'cfs': 6100.582751461575,
#    'huc8': '11010001'},
#   {'ft': 7.0,
#    'm': 2.133599931724802,
#    'cms': 195.27327926543512,
#    'cfs': 6896.011438888066,
#    'huc8': '11010001'},
#   {'ft': 7.5,
#    'm': 2.2859999268480022,
#    'cms': 219.96870409597685,
#    'cfs': 7768.12222004685,
#    'huc8': '11010001'},
#   {'ft': 8.0,
#    'm': 2.4383999219712025,
#    'cms': 244.66412989930387,
#    'cfs': 8640.233035559228,
#    'huc8': '11010001'},
#   {'ft': 8.5,
#    'm': 2.5907999170944027,
#    'cms': 271.26259463558694,
#    'cfs': 9579.549043198662,
#    'huc8': '11010001'},
#   {'ft': 9.0,
#    'm': 2.743199912217603,
#    'cms': 297.8610603462264,
#    'cfs': 10518.865085247171,
#    'huc8': '11010001'},
#   {'ft': 9.5,
#    'm': 2.895599907340803,
#    'cms': 326.74379537104437,
#    'cfs': 11538.849344572165,
#    'huc8': '11010001'},
#   {'ft': 10.0,
#    'm': 3.047999902464003,
#    'cms': 355.6265317116022,
#    'cfs': 12558.83365036208,
#    'huc8': '11010001'}],
#  8589582: [{'ft': 0.5,
#    'm': 0.15239999512320015,
#    'cms': 5.025339999083328,
#    'cfs': 177.46822426674194,
#    'huc8': '11010001'},
#   {'ft': 1.0,
#    'm': 0.3047999902464003,
#    'cms': 10.050679998166656,
#    'cfs': 354.9364485334839,
#    'huc8': '11010001'},
#   {'ft': 1.5,
#    'm': 0.4571999853696005,
#    'cms': 21.561547726382763,
#    'cfs': 761.4389450548115,
#    'huc8': '11010001'},
#   {'ft': 2.0,
#    'm': 0.6095999804928006,
#    'cms': 33.07241586967267,
#    'cfs': 1167.9414562343331,
#    'huc8': '11010001'},
#   {'ft': 2.5,
#    'm': 0.7619999756160007,
#    'cms': 49.49310987231721,
#    'cfs': 1747.832847942842,
#    'huc8': '11010001'},
#   {'ft': 3.0,
#    'm': 0.914399970739201,
#    'cms': 65.91380450341956,
#    'cfs': 2327.7242618451305,
#    'huc8': '11010001'},
#   {'ft': 3.5,
#    'm': 1.066799965862401,
#    'cms': 86.6166003579242,
#    'cfs': 3058.836667836764,
#    'huc8': '11010001'},
#   {'ft': 4.0,
#    'm': 1.2191999609856012,
#    'cms': 107.31939703459247,
#    'cfs': 3789.949102862835,
#    'huc8': '11010001'},
#   {'ft': 4.5,
#    'm': 1.3715999561088015,
#    'cms': 131.92842741884476,
#    'cfs': 4659.008892651425,
#    'huc8': '11010001'},
#   {'ft': 5.0,
#    'm': 1.5239999512320015,
#    'cms': 156.53745880309307,
#    'cfs': 5528.068717754545,
#    'huc8': '11010001'},
#   {'ft': 5.5,
#    'm': 1.6763999463552017,
#    'cms': 184.77248324260052,
#    'cfs': 6525.179291431445,
#    'huc8': '11010001'},
#   {'ft': 6.0,
#    'm': 1.828799941478402,
#    'cms': 213.0075088424261,
#    'cfs': 7522.289906084597,
#    'huc8': '11010001'},
#   {'ft': 6.5,
#    'm': 1.981199936601602,
#    'cms': 244.70473295349814,
#    'cfs': 8641.666919023624,
#    'huc8': '11010001'},
#   {'ft': 7.0,
#    'm': 2.133599931724802,
#    'cms': 276.4019583940549,
#    'cfs': 9761.043978912967,
#    'huc8': '11010001'},
#   {'ft': 7.5,
#    'm': 2.2859999268480022,
#    'cms': 311.4102282497039,
#    'cfs': 10997.349480046467,
#    'huc8': '11010001'},
#   {'ft': 8.0,
#    'm': 2.4383999219712025,
#    'cms': 346.4184995887014,
#    'cfs': 12233.655033563931,
#    'huc8': '11010001'},
#   {'ft': 8.5,
#    'm': 2.5907999170944027,
#    'cms': 384.4677444239368,
#    'cfs': 13577.351562919448,
#    'huc8': '11010001'},
#   {'ft': 9.0,
#    'm': 2.743199912217603,
#    'cms': 422.5169908161513,
#    'cfs': 14921.04814725917,
#    'huc8': '11010001'},
#   {'ft': 9.5,
#    'm': 2.895599907340803,
#    'cms': 463.5622953026854,
#    'cfs': 16370.549534835267,
#    'huc8': '11010001'},
#   {'ft': 10.0,
#    'm': 3.047999902464003,
#    'cms': 504.6076015149498,
#    'cfs': 17820.05098335496,
#    'huc8': '11010001'}]}

# %%
# Flatten into a DataFrame
fim_inputs = pandas.concat(
    [pandas.DataFrame(v).assign(reach_id=k) for k, v in fim_increments.items()],
    ignore_index=True
)
fim_inputs
# Out:
#         ft       m         cms           cfs      huc8  reach_id
# 0      0.5  0.1524    0.813876     28.741746  11010001   8585734
# 1      1.0  0.3048    1.627751     57.483493  11010001   8585734
# 2      1.5  0.4572    3.847128    135.860072  11010001   8585734
# 3      2.0  0.6096    6.066506    214.236655  11010001   8585734
# 4      2.5  0.7620    9.818533    346.738244  11010001   8585734
# ...    ...     ...         ...           ...       ...       ...
# 6600   8.0  2.4384  346.418500  12233.655034  11010001   8589582
# 6601   8.5  2.5908  384.467744  13577.351563  11010001   8589582
# 6602   9.0  2.7432  422.516991  14921.048147  11010001   8589582
# 6603   9.5  2.8956  463.562295  16370.549535  11010001   8589582
# 6604  10.0  3.0480  504.607602  17820.050983  11010001   8589582
#
# [6605 rows x 6 columns]

# %%
# write this to an input file
with open('fim_inputs.txt', 'w') as f:
    for idx, row in fim_inputs.iterrows():
        str_ft = str(round(row.ft, 1)).replace('.','_')
        str_cfs = str(round(row.cfs, 1)).replace('.','_')
        label = f'{row.reach_id}__{str_ft}_ft__{str_cfs}_cfs'
        f.write(f'reachfim,{row.huc8},{row.reach_id},{round(row.cms,5)},{label}\n')
